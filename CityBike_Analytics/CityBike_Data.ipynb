# %%
import pandas as pd
import numpy as np
from pprint import pprint

# %%
df1 = pd.read_csv("Data/Trip/JC-201701-citibike-tripdata.csv")

# %%
df2 = pd.read_csv("Data/Trip/JC-201702-citibike-tripdata.csv")

# %%
df3 = pd.read_csv("Data/Trip/JC-201703-citibike-tripdata.csv")

# %%
df4 = pd.read_csv("Data/Trip/JC-201704-citibike-tripdata.csv")

# %%
d4 = df4.rename(columns={"tripduration": "Trip Duration", "starttime": "Start Time",
                   "stoptime": "Stop Time", "start station id": "Start Station ID",
                   "start station name": "Start Station Name", "start station latitude":"Start Station Latitude",
                   "start station longitude": "Start Station Longitude", "end station id": "End Station ID",
                   "end station name":"End Station Name", "end station latitude": "End Station Latitude",
                   "end station longitude":"End Station Longitude", "bikeid":"Bike ID",
                   "usertype":"User Type", "birth year":"Birth Year", "gender":"Gender"})

# %%
df5 = pd.read_csv("Data/Trip/JC-201705-citibike-tripdata.csv")
d5 = df5.rename(columns={"tripduration": "Trip Duration", "starttime": "Start Time",
                   "stoptime": "Stop Time", "start station id": "Start Station ID",
                   "start station name": "Start Station Name", "start station latitude":"Start Station Latitude",
                   "start station longitude": "Start Station Longitude", "end station id": "End Station ID",
                   "end station name":"End Station Name", "end station latitude": "End Station Latitude",
                   "end station longitude":"End Station Longitude", "bikeid":"Bike ID",
                   "usertype":"User Type", "birth year":"Birth Year", "gender":"Gender"})

# %%
df6 = pd.read_csv("Data/Trip/JC-201706-citibike-tripdata.csv")
d6 = df6.rename(columns={"tripduration": "Trip Duration", "starttime": "Start Time",
                   "stoptime": "Stop Time", "start station id": "Start Station ID",
                   "start station name": "Start Station Name", "start station latitude":"Start Station Latitude",
                   "start station longitude": "Start Station Longitude", "end station id": "End Station ID",
                   "end station name":"End Station Name", "end station latitude": "End Station Latitude",
                   "end station longitude":"End Station Longitude", "bikeid":"Bike ID",
                   "usertype":"User Type", "birth year":"Birth Year", "gender":"Gender"})

# %%
df7 = pd.read_csv("Data/Trip/JC-201707-citibike-tripdata.csv")
d7 = df7.rename(columns={"tripduration": "Trip Duration", "starttime": "Start Time",
                   "stoptime": "Stop Time", "start station id": "Start Station ID",
                   "start station name": "Start Station Name", "start station latitude":"Start Station Latitude",
                   "start station longitude": "Start Station Longitude", "end station id": "End Station ID",
                   "end station name":"End Station Name", "end station latitude": "End Station Latitude",
                   "end station longitude":"End Station Longitude", "bikeid":"Bike ID",
                   "usertype":"User Type", "birth year":"Birth Year", "gender":"Gender"})

# %%
df = pd.concat([df1, df2, df3, d4, d5, d6, d7])

# %%
df.reset_index(drop=True)
# Out:
#         Trip Duration           Start Time            Stop Time  \
# 0                 148  2017-01-01 00:21:32  2017-01-01 00:24:01
# 1                1283  2017-01-01 00:24:35  2017-01-01 00:45:58
# 2                 372  2017-01-01 00:38:19  2017-01-01 00:44:31
# 3                1513  2017-01-01 00:38:37  2017-01-01 01:03:50
# 4                 639  2017-01-01 01:47:52  2017-01-01 01:58:31
# 5                 258  2017-01-01 01:56:29  2017-01-01 02:00:48
# 6                 663  2017-01-01 02:12:34  2017-01-01 02:23:38
# 7                 567  2017-01-01 02:15:52  2017-01-01 02:25:20
# 8                 551  2017-01-01 02:16:03  2017-01-01 02:25:15
# 9                 573  2017-01-01 02:22:17  2017-01-01 02:31:50
# 10                535  2017-01-01 02:22:59  2017-01-01 02:31:55
# 11                224  2017-01-01 02:23:53  2017-01-01 02:27:37
# 12               1699  2017-01-01 02:33:12  2017-01-01 03:01:31
# 13                350  2017-01-01 02:37:31  2017-01-01 02:43:22
# ...

# %%
df.to_csv("Clean_Data.csv")
